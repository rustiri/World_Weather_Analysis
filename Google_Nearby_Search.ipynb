# %% [markdown]
# <h3>6.5.4: Practice Using a Fixed Latitude and Longitude</h3>

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

# %%
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAAFi2A0ClShSdkdelSOmVFhPeRD7hraXk_8B8-3MU0xdgkxMQr4fcbBiv48l-AOqII-nu3QQWQXiMVYBc6WW0KCWzugKnujNBEWUc_FtwhFVubOjNyvWXufYXkkNXlBb1-m6DtdOo4bE1vZeKy_zPr0HBBPrH-3w4Do3kcuK2PObVWa0RHMFF197kHHmMsVAF7BZ0d7uOLTj_2JncP8JdHTg6trb4pMSKXiRbehmSCmQK_HBPduBfCEutVHM_GbQPlcvTLo0JvUgB-bnQz9vNYm3cPRsarBvI2BzwEca62reB69la-GBU-_v-EUBSXLQRp-_saGvO-fSfRKOq7NbWNS-JqTkMXaJl7L2x5JfNNZIRW3kEinDDF9GSHIOTnLvYghIQoacX1WVaVXQzYRTW-mrQBBoUC2lhjx9IlaGJQ5fsTPi9bVmNfbg',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291502},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
# ...

# %%
# To get all the hotels in the results dictionary 
# we can get the length of this dictionary by using, len(hotels["results"])
len(hotels["results"])
# Out:
# 20

# %%
# To retrive the name of the first hotel in the results dictionary
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'

# %% [markdown]
# <h4>Iterate Through hotel_df DataFrame</h4>
# <p>We can use the iterrows() function to perform the iteration; however, we need to provide the index and the row in the for loop using this syntax: for index, row in df.iterrows().</p>
